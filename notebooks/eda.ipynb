# %% [markdown]
# # Emissões de Gases de Efeito Estufa no Brasil (2000-2019)

# %% [markdown]
# ## 1. EDA (Exploratory Data Analysis)

# %%
import pandas as pd
import plotly.express as px
from ydata_profiling import ProfileReport

# %%
df = pd.read_parquet('../data/dataset_clean.parquet')

# %%
df
# Out:
#           ano sigla_uf  nivel_1                               nivel_2  \
# 0        2000       MT  Energia  Emissões pela Queima de Combustíveis
# 1        2000       MT  Energia  Emissões pela Queima de Combustíveis
# 2        2000       MT  Energia  Emissões pela Queima de Combustíveis
# 3        2000       MT  Energia  Emissões pela Queima de Combustíveis
# 4        2000       MT  Energia  Emissões pela Queima de Combustíveis
# ...       ...      ...      ...                                   ...
# 1310695  2019       AM  Energia  Emissões pela Queima de Combustíveis
# 1310696  2019       AM  Energia  Emissões pela Queima de Combustíveis
# 1310697  2019       AM  Energia  Emissões pela Queima de Combustíveis
# 1310698  2019       AM  Energia  Emissões pela Queima de Combustíveis
# 1310699  2019       TO  Energia  Emissões pela Queima de Combustíveis
#
#                           nivel_3                               nivel_4  \
# 0                      Industrial               Mineração e pelotização
# 1                      Industrial               Mineração e pelotização
# 2                      Industrial               Mineração e pelotização
# 3                      Industrial               Mineração e pelotização
# 4                      Industrial               Mineração e pelotização
# ...                           ...                                   ...
# 1310695  Produção de Combustíveis  Exploração de petróleo e gás natural
# 1310696  Produção de Combustíveis  Exploração de petróleo e gás natural
# 1310697  Produção de Combustíveis  Exploração de petróleo e gás natural
# 1310698  Produção de Combustíveis                    Refino de petróleo
# 1310699               Transportes                           Hidroviário
#
#                     nivel_5                            nivel_6 tipo_emissao  \
# 0          Óleo combustível  Centrais Elétricas Autoprodutoras      Emissão
# 1          Óleo combustível  Centrais Elétricas Autoprodutoras      Emissão
# 2          Óleo combustível  Centrais Elétricas Autoprodutoras      Emissão
# 3        Diesel de petróleo  Centrais Elétricas Autoprodutoras      Emissão
# 4               Óleo diesel  Centrais Elétricas Autoprodutoras      Emissão
# ...                     ...                                ...          ...
# 1310695   Gás natural úmido  Centrais Elétricas Autoprodutoras      Emissão
# 1310696   Gás natural úmido  Centrais Elétricas Autoprodutoras      Emissão
# 1310697   Gás natural úmido  Centrais Elétricas Autoprodutoras      Emissão
# 1310698    Gás de refinaria  Centrais Elétricas Autoprodutoras      Emissão
# 1310699         Óleo diesel                        Embarcações      Emissão
#
#                       gas atividade_economica        emissao
# 0                 CH4 (t)            ENE_ELET       0.000060
# 1        CO2e (t) GWP-AR5            ENE_ELET       5.802007
# 2                 N2O (t)            ENE_ELET       0.000022
# 3        CO2e (t) GWP-AR5            ENE_ELET       0.000000
# 4               COVNM (t)            ENE_ELET       0.000000
# ...                   ...                 ...            ...
# 1310695           CH4 (t)            ENE_ELET      12.309746
# 1310696  CO2e (t) GTP-AR2            ENE_ELET  173536.640000
# 1310697           N2O (t)            ENE_ELET       3.077437
# 1310698           CH4 (t)            ENE_ELET       1.018040
# 1310699  CO2e (t) GTP-AR5          TRAN_CARGA      14.203861
#
# [1310700 rows x 12 columns]

# %%
# ProfileReport(df)

# %%
df.sort_values('emissao')
# Out:
#           ano sigla_uf                             nivel_1  \
# 1290359  2019       AM  Mudança de Uso da Terra e Floresta
# 1303881  2019       AM  Mudança de Uso da Terra e Floresta
# 1303882  2019       AM  Mudança de Uso da Terra e Floresta
# 1303899  2019       AM  Mudança de Uso da Terra e Floresta
# 1292058  2019       AM  Mudança de Uso da Terra e Floresta
# ...       ...      ...                                 ...
# 325239   2004       MT  Mudança de Uso da Terra e Floresta
# 282975   2004       MT  Mudança de Uso da Terra e Floresta
# 325240   2004       MT  Mudança de Uso da Terra e Floresta
# 318364   2004       MT  Mudança de Uso da Terra e Floresta
# 282974   2004       MT  Mudança de Uso da Terra e Floresta
#
#                              nivel_2   nivel_3                 nivel_4  \
# 1290359  Remoção em Áreas Protegidas  Amazônia       em Área Protegida
# 1303881  Remoção em Áreas Protegidas  Amazônia       em Área Protegida
# 1303882  Remoção em Áreas Protegidas  Amazônia       em Área Protegida
# 1303899  Remoção em Áreas Protegidas  Amazônia       em Área Protegida
# 1292058  Remoção em Áreas Protegidas  Amazônia       em Área Protegida
# ...                              ...       ...                     ...
# 325239     Alterações de Uso do Solo  Amazônia  fora de Área Protegida
# 282975     Alterações de Uso do Solo  Amazônia  fora de Área Protegida
# 325240     Alterações de Uso do Solo  Amazônia  fora de Área Protegida
# 318364     Alterações de Uso do Solo  Amazônia  fora de Área Protegida
# 282974     Alterações de Uso do Solo  Amazônia  fora de Área Protegida
#
#                           nivel_5                                 nivel_6  \
# 1290359  Vegetação nativa estável  Floresta primária -- Floresta primária
# 1303881  Vegetação nativa estável  Floresta primária -- Floresta primária
# 1303882  Vegetação nativa estável  Floresta primária -- Floresta primária
# 1303899  Vegetação nativa estável  Floresta primária -- Floresta primária
# 1292058  Vegetação nativa estável  Floresta primária -- Floresta primária
# ...                           ...                                     ...
# 325239               Desmatamento   Floresta primária -- Uso agropecuário
# 282975               Desmatamento   Floresta primária -- Uso agropecuário
# 325240               Desmatamento   Floresta primária -- Uso agropecuário
# 318364               Desmatamento   Floresta primária -- Uso agropecuário
# 282974               Desmatamento   Floresta primária -- Uso agropecuário
#
#         tipo_emissao               gas atividade_economica      emissao
# 1290359      Remoção  CO2e (t) GWP-AR2         Conservação -132800000.0
# 1303881      Remoção  CO2e (t) GTP-AR5         Conservação -132800000.0
# 1303882      Remoção  CO2e (t) GTP-AR2         Conservação -132800000.0
# 1303899      Remoção  CO2e (t) GWP-AR5         Conservação -132800000.0
# 1292058      Remoção  CO2e (t) GTP-AR4         Conservação -132800000.0
# ...              ...               ...                 ...          ...
# 325239       Emissão  CO2e (t) GWP-AR2             AGROPEC  515600000.0
# 282975       Emissão  CO2e (t) GTP-AR4             AGROPEC  515600000.0
# 325240       Emissão           CO2 (t)             AGROPEC  515600000.0
# 318364       Emissão  CO2e (t) GTP-AR2             AGROPEC  515600000.0
# 282974       Emissão  CO2e (t) GWP-AR4             AGROPEC  515600000.0
#
# [1310700 rows x 12 columns]

# %%
df_not_emission = df.query('emissao < 0')
df_not_emission.head()
# Out:
#       ano sigla_uf                             nivel_1  \
# 121  2000       AL  Mudança de Uso da Terra e Floresta
# 122  2000       AL  Mudança de Uso da Terra e Floresta
# 123  2000       AL  Mudança de Uso da Terra e Floresta
# 194  2000       MA  Mudança de Uso da Terra e Floresta
# 198  2000       TO  Mudança de Uso da Terra e Floresta
#
#                                  nivel_2   nivel_3                 nivel_4  \
# 121  Remoção por Mudança de Uso da Terra  Caatinga       em Área Protegida
# 122  Remoção por Mudança de Uso da Terra  Caatinga       em Área Protegida
# 123  Remoção por Mudança de Uso da Terra  Caatinga       em Área Protegida
# 194     Remoção por Vegetação Secundária   Cerrado  fora de Área Protegida
# 198     Remoção por Vegetação Secundária   Cerrado  fora de Área Protegida
#
#          nivel_5                                            nivel_6  \
# 121  Regeneração            Uso agropecuário -- Floresta secundária
# 122  Regeneração            Uso agropecuário -- Floresta secundária
# 123  Regeneração            Uso agropecuário -- Floresta secundária
# 194  Regeneração  Área sem vegetação -- Vegetação não florestal ...
# 198  Regeneração  Área sem vegetação -- Vegetação não florestal ...
#
#     tipo_emissao               gas atividade_economica  emissao
# 121      Remoção  CO2e (t) GWP-AR2             AGROPEC    -11.0
# 122      Remoção  CO2e (t) GTP-AR5             AGROPEC    -11.0
# 123      Remoção  CO2e (t) GTP-AR2             AGROPEC    -11.0
# 194      Remoção           CO2 (t)             AGROPEC   -836.0
# 198      Remoção  CO2e (t) GWP-AR5             AGROPEC   -968.0

# %%
df_not_emission['tipo_emissao'].value_counts()
# Out:
# Remoção          100450
# Remoção proxy     13580
# Name: tipo_emissao, dtype: int64

# %%
for col in df_not_emission.columns:
  if 'nivel_' in col:
    print(f'\n{col}:')
    print(df_not_emission[col].unique())
# Out:
# nivel_1:
# ['Mudança de Uso da Terra e Floresta']
#
# nivel_2:
# ['Remoção por Mudança de Uso da Terra' 'Remoção por Vegetação Secundária'
#  'Remoção em Áreas Protegidas']
#
# nivel_3:
# ['Caatinga' 'Cerrado' 'Mata Atlântica' 'Pampa' 'Amazônia' 'Pantanal']
#
# nivel_4:
# ['em Área Protegida' 'fora de Área Protegida' 'NÃO SE APLICA']
#
# nivel_5:
# ['Regeneração' 'Vegetação nativa estável' 'Desmatamento'
#  'Outras Mudanças de uso da terra' 'NÃO SE APLICA']
#
# nivel_6:
# ['Uso agropecuário -- Floresta secundária'
#  'Área sem vegetação -- Vegetação não florestal secundária'
#  'Vegetação não florestal primária -- Vegetação não florestal primária'
#  'Vegetação não florestal secundária -- Silvicultura'
#  'Área sem vegetação -- Silvicultura'
#  'Vegetação não florestal primária -- Silvicultura'
#  'Vegetação não florestal secundária -- Uso agropecuário'
#  'Uso agropecuário -- Silvicultura'
#  'Floresta primária -- Floresta primária'
#  'Uso agropecuário -- Uso agropecuário'
#  'Área sem vegetação -- Floresta secundária'
#  'Área sem vegetação -- Uso agropecuário'
#  'Floresta secundária -- Silvicultura'
#  'Vegetação não florestal secundária -- Vegetação não florestal secundária'
#  'NÃO SE APLICA' 'Floresta secundária -- Floresta secundária']

# %%
df_not_emission.query('nivel_5 == "Desmatamento"')
# Out:
#           ano sigla_uf                             nivel_1  \
# 353      2000       RS  Mudança de Uso da Terra e Floresta
# 385      2000       RS  Mudança de Uso da Terra e Floresta
# 758      2000       SC  Mudança de Uso da Terra e Floresta
# 781      2000       SC  Mudança de Uso da Terra e Floresta
# 1879     2000       SP  Mudança de Uso da Terra e Floresta
# ...       ...      ...                                 ...
# 1308975  2019       SE  Mudança de Uso da Terra e Floresta
# 1308998  2019       PR  Mudança de Uso da Terra e Floresta
# 1308999  2019       PR  Mudança de Uso da Terra e Floresta
# 1309002  2019       RJ  Mudança de Uso da Terra e Floresta
# 1309027  2019       SP  Mudança de Uso da Terra e Floresta
#
#                                      nivel_2         nivel_3  \
# 353      Remoção por Mudança de Uso da Terra  Mata Atlântica
# 385      Remoção por Mudança de Uso da Terra           Pampa
# 758      Remoção por Mudança de Uso da Terra  Mata Atlântica
# 781      Remoção por Mudança de Uso da Terra  Mata Atlântica
# 1879     Remoção por Mudança de Uso da Terra  Mata Atlântica
# ...                                      ...             ...
# 1308975  Remoção por Mudança de Uso da Terra  Mata Atlântica
# 1308998  Remoção por Mudança de Uso da Terra  Mata Atlântica
# 1308999  Remoção por Mudança de Uso da Terra  Mata Atlântica
# 1309002  Remoção por Mudança de Uso da Terra  Mata Atlântica
# 1309027  Remoção por Mudança de Uso da Terra  Mata Atlântica
#
#                         nivel_4       nivel_5  \
# 353      fora de Área Protegida  Desmatamento
# 385      fora de Área Protegida  Desmatamento
# 758      fora de Área Protegida  Desmatamento
# 781      fora de Área Protegida  Desmatamento
# 1879     fora de Área Protegida  Desmatamento
# ...                         ...           ...
# 1308975  fora de Área Protegida  Desmatamento
# 1308998  fora de Área Protegida  Desmatamento
# 1308999  fora de Área Protegida  Desmatamento
# 1309002       em Área Protegida  Desmatamento
# 1309027       em Área Protegida  Desmatamento
#
#                                                    nivel_6 tipo_emissao  \
# 353      Vegetação não florestal secundária -- Silvicul...      Remoção
# 385       Vegetação não florestal primária -- Silvicultura      Remoção
# 758      Vegetação não florestal secundária -- Silvicul...      Remoção
# 781      Vegetação não florestal secundária -- Silvicul...      Remoção
# 1879     Vegetação não florestal secundária -- Uso agro...      Remoção
# ...                                                    ...          ...
# 1308975  Vegetação não florestal secundária -- Uso agro...      Remoção
# 1308998  Vegetação não florestal secundária -- Uso agro...      Remoção
# 1308999  Vegetação não florestal secundária -- Uso agro...      Remoção
# 1309002  Vegetação não florestal secundária -- Uso agro...      Remoção
# 1309027  Vegetação não florestal secundária -- Uso agro...      Remoção
#
#                       gas atividade_economica  emissao
# 353      CO2e (t) GTP-AR5             AGROPEC   -134.0
# 385               CO2 (t)             AGROPEC  -2305.0
# 758      CO2e (t) GWP-AR4             AGROPEC  -1917.0
# 781               CO2 (t)             AGROPEC  -1917.0
# 1879     CO2e (t) GWP-AR4             AGROPEC    -50.0
# ...                   ...                 ...      ...
# 1308975  CO2e (t) GWP-AR5             AGROPEC    -62.0
# 1308998           CO2 (t)             AGROPEC    -14.0
# 1308999  CO2e (t) GTP-AR5             AGROPEC    -14.0
# 1309002           CO2 (t)             AGROPEC     -8.0
# 1309027  CO2e (t) GTP-AR4             AGROPEC    -45.0
#
# [7189 rows x 12 columns]

# %%
df.query('nivel_5 == "Desmatamento"')['tipo_emissao'].value_counts()
# Out:
# Emissão    116060
# Remoção      9520
# Name: tipo_emissao, dtype: int64

# %%
df_emissions = df.drop(df_not_emission.index)
df_emissions.head()
# Out:
#     ano sigla_uf  nivel_1                               nivel_2     nivel_3  \
# 0  2000       MT  Energia  Emissões pela Queima de Combustíveis  Industrial
# 1  2000       MT  Energia  Emissões pela Queima de Combustíveis  Industrial
# 2  2000       MT  Energia  Emissões pela Queima de Combustíveis  Industrial
# 3  2000       MT  Energia  Emissões pela Queima de Combustíveis  Industrial
# 4  2000       MT  Energia  Emissões pela Queima de Combustíveis  Industrial
#
#                    nivel_4             nivel_5  \
# 0  Mineração e pelotização    Óleo combustível
# 1  Mineração e pelotização    Óleo combustível
# 2  Mineração e pelotização    Óleo combustível
# 3  Mineração e pelotização  Diesel de petróleo
# 4  Mineração e pelotização         Óleo diesel
#
#                              nivel_6 tipo_emissao               gas  \
# 0  Centrais Elétricas Autoprodutoras      Emissão           CH4 (t)
# 1  Centrais Elétricas Autoprodutoras      Emissão  CO2e (t) GWP-AR5
# 2  Centrais Elétricas Autoprodutoras      Emissão           N2O (t)
# 3  Centrais Elétricas Autoprodutoras      Emissão  CO2e (t) GWP-AR5
# 4  Centrais Elétricas Autoprodutoras      Emissão         COVNM (t)
#
#   atividade_economica   emissao
# 0            ENE_ELET  0.000060
# 1            ENE_ELET  5.802007
# 2            ENE_ELET  0.000022
# 3            ENE_ELET  0.000000
# 4            ENE_ELET  0.000000

# %%
for col in df_emissions.columns:
  if 'nivel_' in col:
    print(f'\n{col}:')
    print(df_emissions[col].unique())
# Out:
# nivel_1:
# ['Energia' 'Agropecuária' 'Mudança de Uso da Terra e Floresta' 'Resíduos '
#  'Processos Industriais' '']
#
# nivel_2:
# ['Emissões pela Queima de Combustíveis' 'Solos Manejados'
#  'Alterações de Uso do Solo' 'Resíduos Sólidos'
#  'Remoção por Vegetação Secundária' 'Efluentes Líquidos'
#  'Cultivo do Arroz' 'Fermentação Entérica' 'Manejo de Dejetos Animais'
#  'Queima de Resíduos Agrícolas' 'Remoção por Mudança de Uso da Terra'
#  'Remoção em Áreas Protegidas' 'Produção de Metais' 'Produtos Minerais'
#  'Indústria Química' 'Emissões Fugitivas' 'Resíduos Florestais'
#  'Emissões de HFCs'
#  'Uso Não-Energético de Combustíveis e Uso de Solventes' 'Uso de SF6' '']
#
# nivel_3:
# ['Industrial' 'Comercial' 'Agropecuário' 'Indiretas' 'Público'
#  'Residencial' 'Transportes' 'Cerrado' 'Produção de Combustíveis'
#  'Incineração ou queima a céu aberto' 'Amazônia' 'Mata Atlântica'
#  'Diretas' 'Disposição Final de Resíduos Sólidos' 'Caatinga'
#  'Efluentes Líquidos Industriais ' 'Pampa' 'Pantanal'
#  'Tratamento Biológico de Resíduos Sólidos'
#  'Efluentes Líquidos Domésticos' 'Não Identificado'
#  'Geração de Eletricidade (Serviço Público)'
#  'Produção de Ferro Gusa e Aço' 'Produção de Cimento'
#  'Produção de Ácido Nítrico' 'Produção de Ácido Adípico'
#  'Produção de Ferroligas' 'Produção de Vidro' 'Produção de Cal'
#  'Produção de Óxido de Eteno' 'Produção de Poliestireno'
#  'Produção de Carbureto de Cálcio' 'NÃO SE APLICA' 'Produção de Amônia'
#  'Produção de Alumínio' 'Produção de Magnésio' 'Produção de Caprolactama'
#  'Produção de Acrilonitrila' 'Consumo Final Não Energético'
#  'Produção de Outros Não-Ferrosos' 'Consumo de Barrilha'
#  'Produção de Ácido Fosfórico' 'Produção de Metanol'
#  'Produção de Polietileno PEBD' 'Produção de Estireno' 'Produção de Eteno'
#  'Produção de Coque de Petróleo Calcinado' 'Equipamentos Elétricos'
#  'Produção de Cloreto de Vinila' 'Produção de Polietileno PEAD'
#  'Produção de PVC' 'Produção de Negro-de-fumo'
#  'Produção de Borracha de butadieno estireno (SBR)'
#  'Produção de Anidrido Ftálico' 'Produção de ABS'
#  'Produção de Polipropileno' 'Produção de Polietileno PELBD'
#  'Produção de Dicloroetano' 'Produção de Etilbenzeno'
#  'Produção de Formaldeído' 'Produção de Propeno' '']
#
# nivel_4:
# ['Mineração e pelotização' 'Ferro gusa e aço' 'Outras indústrias'
#  'Papel e celulose' 'Cerâmica' 'Alimentos e bebidas' 'NÃO SE APLICA'
#  'Lixiviação' 'Deposição Atmosférica' 'Cimento' 'Química' 'Têxtil'
#  'Rodoviário' 'em Área Protegida' 'Exploração de petróleo e gás natural'
#  'Queima de Resíduos a Céu Aberto'
#  'Tratamento de Resíduos por Incineração'
#  'Tratamento de Resíduos por Incineração ' 'fora de Área Protegida'
#  'Resíduos Agrícolas' 'Deposição de dejetos em pastagem'
#  'Resíduos Sólidos Urbanos' 'Aplicação de resíduos orgânicos'
#  'Não ferrosos e outros da metalurgia' 'Produção de Leite Cru '
#  'Produção de Leite Pasteurizado ' 'Lodo de ETE' 'Ferro Ligas' 'Outros'
#  'Fertilizantes Sintéticos' 'Produção de Carne Avícola'
#  'Produção de Carne Bovina' 'Produção de Carne Suína'
#  'Produção de Celulose' 'Refino de petróleo' 'Aéreo' 'Solos orgânicos'
#  'Produção de carvão vegetal' 'Transporte de gás natural'
#  'Produção de álcool' 'Produção de carvão mineral e outros' 'Hidroviário'
#  'Resíduos de Serviços de Saúde ' 'Ferroviário' 'Produção de Cerveja'
#  'Consumo de Combustíveis Redutores' 'Consumo de Dolomita'
#  'Cal Magnesiana' 'Cal Dolomítica' 'Cal Calcítica'
#  'Tecnologia Prebaked Anode' 'Tecnologia Soderberg' 'Uso de SF6'
#  'Consumo em Outros Setores' 'Consumo de Calcário' '']
#
# nivel_5:
# ['Óleo combustível' 'Diesel de petróleo' 'Óleo diesel' 'Gás natural seco'
#  'GLP' 'Animal' 'Outros' 'Coque de petróleo' 'Desmatamento'
#  'Gás natural úmido' 'Resíduos Sólidos Urbanos'
#  'Resíduos de Serviços de Saúde ' 'Regeneração' 'Vegetal'
#  'Disposição em Aterro Sanitário'
#  'Disposição em Aterro Controlado ou Lixão' 'Gasolina automotiva'
#  'Álcool hidratado' 'Gasolina C' 'NÃO SE APLICA'
#  'Outras Mudanças de uso da terra' 'Compostagem' 'Gás canalizado SP'
#  'Gás de refinaria' 'Biogás' 'Bagaço de cana' 'Querosene de aviação'
#  'Gasolina de aviação' 'Lenha carvoejamento' 'Gás canalizado RJ'
#  'Outras biomassas' 'Outras não renováveis' 'Nafta' 'Lenha'
#  'Outros energéticos de petróleo' 'Carvão vegetal'
#  'Carvão vapor sem especificação' 'Carvão vapor 6000' 'Carvão vapor 5900'
#  'Carvão vapor 5200' 'Carvão vapor 4700' 'Carvão vapor 4500'
#  'Querosene iluminante' 'Carvão vapor 4200' 'Carvão vapor 3300'
#  'Carvão vapor 3100' 'Coque de carvão mineral' 'Carvão vapor 3700'
#  'Lixívia' 'Gás de coqueria' 'Alcatrão' 'Vegetação nativa estável'
#  'Consumo de Combustíveis Renováveis' 'Gás natural'
#  'Petróleo e gás natural' 'Petróleo' 'Consumo de Combustíveis Fósseis'
#  'Carvão mineral' 'Lubrificantes' 'Outros não energéticos de petróleo'
#  'Álcool anidro' 'Solventes' '']
#
# nivel_6:
# ['Centrais Elétricas Autoprodutoras' 'Consumo Final Energético' 'Bubalino'
#  'Fertilizantes Sintéticos' 'Ônibus'
#  'Floresta primária -- Uso agropecuário' 'NÃO SE APLICA'
#  'Uso agropecuário -- Floresta secundária' 'Soja' 'Caprino' 'Equino'
#  'Muar' 'Asinino' 'Aves' 'Ovino' 'Comerciais Leves'
#  'Área sem vegetação -- Vegetação não florestal secundária'
#  'Silvicultura -- Área sem vegetação'
#  'Silvicultura -- Vegetação não florestal secundária'
#  'Vegetação não florestal primária -- Silvicultura' 'Arroz' 'Algodão'
#  'Milho' 'Outras Culturas' 'Área sem vegetação -- Silvicultura'
#  'Cana de Açucar' 'Vegetação não florestal secundária -- Silvicultura'
#  'Caminhões' 'Motocicletas'
#  'Uso agropecuário -- Vegetação não florestal secundária' 'Aeronaves'
#  'Vegetação não florestal primária -- Uso agropecuário' 'Automóveis'
#  'Vegetação não florestal secundária -- Uso agropecuário'
#  'Silvicultura -- Floresta secundária' 'Solos orgânicos' 'Suínos'
#  'Carvoarias' 'Uso agropecuário -- Silvicultura' 'Embarcações'
#  'Floresta primária -- Área sem vegetação'
#  'Floresta primária -- Floresta primária'
#  'Silvicultura -- Uso agropecuário'
#  'Vegetação não florestal primária -- Área sem vegetação'
#  'Uso agropecuário -- Uso agropecuário' 'Locomotivas' 'Feijão'
#  'Área sem vegetação -- Floresta secundária'
#  'Vegetação não florestal secundária -- Área sem vegetação' 'Mandioca'
#  'Área sem vegetação -- Uso agropecuário' 'Gado de Leite'
#  'Vegetação não florestal primária -- Vegetação não florestal primária'
#  'Floresta secundária -- Silvicultura'
#  'Centrais Elétricas de Serviço Público'
#  'Vegetação não florestal secundária -- Vegetação não florestal secundária'
#  'Gado de Corte' 'Floresta secundária -- Uso agropecuário'
#  'Floresta secundária -- Área sem vegetação'
#  'Floresta primária -- Silvicultura'
#  'Uso agropecuário -- Área sem vegetação'
#  'Floresta secundária -- Floresta secundária' '']

# %%
df.query('nivel_5 == "Vegetal"').head()
# Out:
#       ano sigla_uf       nivel_1                       nivel_2  nivel_3  \
# 141  2000       RR  Agropecuária               Solos Manejados  Diretas
# 328  2000       RS  Agropecuária              Cultivo do Arroz  Diretas
# 338  2000       RS  Agropecuária  Queima de Resíduos Agrícolas  Diretas
# 342  2000       RS  Agropecuária               Solos Manejados  Diretas
# 343  2000       RS  Agropecuária               Solos Manejados  Diretas
#
#                 nivel_4  nivel_5  nivel_6 tipo_emissao               gas  \
# 141  Resíduos Agrícolas  Vegetal     Soja      Emissão  CO2e (t) GWP-AR5
# 328              Outros  Vegetal    Arroz      Emissão  CO2e (t) GWP-AR5
# 338              Outros  Vegetal  Algodão      Emissão            CO (t)
# 342  Resíduos Agrícolas  Vegetal    Arroz      Emissão  CO2e (t) GWP-AR5
# 343  Resíduos Agrícolas  Vegetal    Milho      Emissão  CO2e (t) GWP-AR5
#
#     atividade_economica     emissao
# 141                 AGR        0.00
# 328                 AGR  8327760.00
# 338                 AGR        0.00
# 342                 AGR   151585.21
# 343                 AGR   169986.10

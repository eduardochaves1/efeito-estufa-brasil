# %% [markdown]
# # Emissões de Gases de Efeito Estufa no Brasil (2000-2019)

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)
#
# Fase de análise exploratória inicial do dataset utilizado

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import ydata_profiling

# %%
sns.set_theme(style='darkgrid')

# %%
df = pd.read_parquet('./dataset.parquet')

# %%
df
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1973       AC                        Agropecuária
# 1        1973       AC                        Agropecuária
# 2        1973       AC                        Agropecuária
# 3        1973       AC                        Agropecuária
# 4        1973       AC                        Agropecuária
# ...       ...      ...                                 ...
# 3276745  2012       SP  Mudança de Uso da Terra e Floresta
# 3276746  2012       SP  Mudança de Uso da Terra e Floresta
# 3276747  2012       TO  Mudança de Uso da Terra e Floresta
# 3276748  2012       TO  Mudança de Uso da Terra e Floresta
# 3276749  2012       TO  Mudança de Uso da Terra e Floresta
#
#                                   nivel_2         nivel_3  \
# 0                    Fermentação Entérica         Diretas
# 1               Manejo de Dejetos Animais         Diretas
# 2               Manejo de Dejetos Animais         Diretas
# ...

# %%
df = df.sort_values('ano').reset_index(drop=True)
df
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1970       PI  Mudança de Uso da Terra e Floresta
# 1        1970       PI                             Energia
# 2        1970       PI                             Energia
# 3        1970       PI                             Energia
# 4        1970       PI                             Energia
# ...       ...      ...                                 ...
# 3276745  2019       AM                             Energia
# 3276746  2019       AM                             Energia
# 3276747  2019       AM                             Energia
# 3276748  2019       AM                             Energia
# 3276749  2019       TO                             Energia
#
#                                       nivel_2                   nivel_3  \
# 0                   Alterações de Uso do Solo                  Caatinga
# 1        Emissões pela Queima de Combustíveis                Industrial
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276750 entries, 0 to 3276749
# Data columns (total 13 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ano                  Int64
#  1   sigla_uf             object
#  2   nivel_1              object
#  3   nivel_2              object
#  4   nivel_3              object
#  5   nivel_4              object
#  6   nivel_5              object
#  7   nivel_6              object
#  8   tipo_emissao         object
#  9   gas                  object
#  10  atividade_economica  object
#  11  produto              object
#  12  emissao              float64
# dtypes: Int64(1), float64(1), object(11)
# memory usage: 328.1+ MB

# %%
# df.duplicated().sum()
# commented this line to save some time as the result was 0

# %%
df.isnull().sum()
# Out:
# ano                          0
# sigla_uf                     0
# nivel_1                      0
# nivel_2                      0
# nivel_3                      0
# nivel_4                      0
# nivel_5                      0
# nivel_6                      0
# tipo_emissao                 0
# gas                          0
# atividade_economica          0
# produto                1395600
# emissao                 317112
# dtype: int64

# %%
emissao_null = df[df['emissao'].isnull()]
emissao_null
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1970       PI  Mudança de Uso da Terra e Floresta
# 80       1970       MG  Mudança de Uso da Terra e Floresta
# 81       1970       MG  Mudança de Uso da Terra e Floresta
# 82       1970       MG  Mudança de Uso da Terra e Floresta
# 83       1970       MS  Mudança de Uso da Terra e Floresta
# ...       ...      ...                                 ...
# 1310699  1989       MS  Mudança de Uso da Terra e Floresta
# 1311589  1990       RR                        Agropecuária
# 1332532  1990       RR                        Agropecuária
# 1541164  1993       RR                        Agropecuária
# 1566279  1993       RR                        Agropecuária
#
#                                      nivel_2         nivel_3  \
# 0                  Alterações de Uso do Solo        Caatinga
# 80       Remoção por Mudança de Uso da Terra  Mata Atlântica
# 81       Remoção por Mudança de Uso da Terra  Mata Atlântica
# ...

# %%
emissao_null['produto'].value_counts()
# Out:
# NÃO SE APLICA    317100
# CAR                  12
# Name: produto, dtype: int64

# %%
emissao_null['tipo_emissao'].value_counts()
# Out:
# Emissão    204272
# Remoção    112840
# Name: tipo_emissao, dtype: int64

# %%
emissao_null['nivel_5'].value_counts()
# Out:
# Desmatamento                       125580
# Outras Mudanças de uso da terra     82180
# Regeneração                         61180
# Vegetação nativa estável            40320
# NÃO SE APLICA                        7840
# Animal                                 12
# Name: nivel_5, dtype: int64

# %% [markdown]
# ### 1.1 Data Visualization

# %%
df_gruped_by_year = df.groupby('ano', as_index=False).sum('numeric_only')

# %%
df_gruped_by_year.head()
# Out:
#     ano       emissao
# 0  1970  1.005415e+09
# 1  1971  1.094097e+09
# 2  1972  1.177206e+09
# 3  1973  1.321266e+09
# 4  1974  1.417999e+09

# %%
sns.lineplot(data=df_gruped_by_year, x='ano', y='emissao')
# Out:
# <AxesSubplot: xlabel='ano', ylabel='emissao'>

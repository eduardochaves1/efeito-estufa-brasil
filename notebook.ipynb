# %% [markdown]
# # Emissões de Gases de Efeito Estufa no Brasil (2000-2019)

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)
#
# Fase de análise exploratória inicial do dataset utilizado

# %%
import pandas as pd
import plotly.express as px
from pandas_profiling import ProfileReport

# %%
df = pd.read_parquet('./dataset.parquet')

# %%
df
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1973       AC                        Agropecuária
# 1        1973       AC                        Agropecuária
# 2        1973       AC                        Agropecuária
# 3        1973       AC                        Agropecuária
# 4        1973       AC                        Agropecuária
# ...       ...      ...                                 ...
# 3276745  2012       SP  Mudança de Uso da Terra e Floresta
# 3276746  2012       SP  Mudança de Uso da Terra e Floresta
# 3276747  2012       TO  Mudança de Uso da Terra e Floresta
# 3276748  2012       TO  Mudança de Uso da Terra e Floresta
# 3276749  2012       TO  Mudança de Uso da Terra e Floresta
#
#                                   nivel_2         nivel_3  \
# 0                    Fermentação Entérica         Diretas
# 1               Manejo de Dejetos Animais         Diretas
# 2               Manejo de Dejetos Animais         Diretas
# 3               Manejo de Dejetos Animais         Diretas
# 4                         Solos Manejados         Diretas
# ...                                   ...             ...
# 3276745  Remoção por Vegetação Secundária  Mata Atlântica
# 3276746  Remoção por Vegetação Secundária  Mata Atlântica
# 3276747  Remoção por Vegetação Secundária        Amazônia
# 3276748  Remoção por Vegetação Secundária        Amazônia
# 3276749  Remoção por Vegetação Secundária         Cerrado
#
#                                   nivel_4                   nivel_5  \
# 0                                  Outros                    Animal
# 1                                  Outros                    Animal
# 2                                  Outros                    Animal
# 3                                  Outros                    Animal
# 4        Deposição de dejetos em pastagem                    Animal
# ...                                   ...                       ...
# 3276745                 em Área Protegida  Vegetação nativa estável
# 3276746            fora de Área Protegida  Vegetação nativa estável
# 3276747                 em Área Protegida  Vegetação nativa estável
# 3276748            fora de Área Protegida  Vegetação nativa estável
# 3276749            fora de Área Protegida  Vegetação nativa estável
#
#                                                    nivel_6 tipo_emissao  \
# 0                                                 Bubalino      Emissão
# 1                                                     Aves      Emissão
# 2                                                     Aves      Emissão
# 3                                                     Aves      Emissão
# 4                                                 Bubalino      Emissão
# ...                                                    ...          ...
# 3276745  Vegetação não florestal secundária -- Vegetaçã...      Remoção
# 3276746  Vegetação não florestal secundária -- Vegetaçã...      Remoção
# 3276747  Vegetação não florestal secundária -- Vegetaçã...      Remoção
# 3276748  Vegetação não florestal secundária -- Vegetaçã...      Remoção
# 3276749  Vegetação não florestal secundária -- Vegetaçã...      Remoção
#
#                       gas atividade_economica        produto        emissao
# 0        CO2e (t) GWP-AR5                 PEC           None      24.640000
# 1        CO2e (t) GTP-AR5                 PEC            CAR     205.218890
# 2        CO2e (t) GWP-AR5                 PEC            CAR     650.668810
# 3                 N2O (t)                 PEC            CAR       0.572370
# 4        CO2e (t) GWP-AR5                 PEC           None       5.914485
# ...                   ...                 ...            ...            ...
# 3276745  CO2e (t) GTP-AR4             AGROPEC  NÃO SE APLICA   -6689.000000
# 3276746  CO2e (t) GTP-AR4             AGROPEC  NÃO SE APLICA  -41756.000000
# 3276747  CO2e (t) GTP-AR5             AGROPEC  NÃO SE APLICA      -5.000000
# 3276748  CO2e (t) GWP-AR4             AGROPEC  NÃO SE APLICA   -1521.000000
# 3276749  CO2e (t) GTP-AR2             AGROPEC  NÃO SE APLICA -220189.000000
#
# [3276750 rows x 13 columns]

# %%
df = df.sort_values('ano').reset_index(drop=True)
df
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1970       PI  Mudança de Uso da Terra e Floresta
# 1        1970       RJ                             Energia
# 2        1970       RJ                             Energia
# 3        1970       RN                             Energia
# 4        1970       RN                             Energia
# ...       ...      ...                                 ...
# 3276745  2019       PR                             Energia
# 3276746  2019       PR                             Energia
# 3276747  2019       PR                             Energia
# 3276748  2019       PE                             Energia
# 3276749  2019       TO                             Energia
#
#                                       nivel_2                   nivel_3  \
# 0                   Alterações de Uso do Solo                  Caatinga
# 1        Emissões pela Queima de Combustíveis  Produção de Combustíveis
# 2        Emissões pela Queima de Combustíveis  Produção de Combustíveis
# 3        Emissões pela Queima de Combustíveis              Agropecuário
# 4        Emissões pela Queima de Combustíveis              Agropecuário
# ...                                       ...                       ...
# 3276745  Emissões pela Queima de Combustíveis                Industrial
# 3276746  Emissões pela Queima de Combustíveis                 Comercial
# 3276747  Emissões pela Queima de Combustíveis                 Comercial
# 3276748  Emissões pela Queima de Combustíveis                Industrial
# 3276749  Emissões pela Queima de Combustíveis               Transportes
#
#                                       nivel_4           nivel_5  \
# 0                      fora de Área Protegida      Desmatamento
# 1        Exploração de petróleo e gás natural  Gás natural seco
# 2        Exploração de petróleo e gás natural  Gás natural seco
# 3                               NÃO SE APLICA               GLP
# 4                               NÃO SE APLICA               GLP
# ...                                       ...               ...
# 3276745                   Alimentos e bebidas  Gás natural seco
# 3276746                         NÃO SE APLICA       Óleo diesel
# 3276747                         NÃO SE APLICA  Óleo combustível
# 3276748                     Outras indústrias  Óleo combustível
# 3276749                           Hidroviário       Óleo diesel
#
#                                                    nivel_6 tipo_emissao  \
# 0        Vegetação não florestal secundária -- Área sem...      Emissão
# 1                                 Consumo Final Energético      Emissão
# 2                                 Consumo Final Energético      Emissão
# 3                                 Consumo Final Energético      Emissão
# 4                                 Consumo Final Energético      Emissão
# ...                                                    ...          ...
# 3276745                  Centrais Elétricas Autoprodutoras      Emissão
# 3276746                  Centrais Elétricas Autoprodutoras      Emissão
# 3276747                  Centrais Elétricas Autoprodutoras      Emissão
# 3276748                           Consumo Final Energético      Emissão
# 3276749                                        Embarcações      Emissão
#
#                       gas atividade_economica        produto       emissao
# 0        CO2e (t) GTP-AR5             AGROPEC  NÃO SE APLICA           NaN
# 1                 CH4 (t)           PROD_COMB           None      0.000000
# 2               COVNM (t)           PROD_COMB           None      0.000000
# 3        CO2e (t) GWP-AR2             AGROPEC           None      0.000000
# 4        CO2e (t) GWP-AR5             AGROPEC           None      0.000000
# ...                   ...                 ...            ...           ...
# 3276745           CO2 (t)            ENE_ELET       ENE_ELET  12213.170000
# 3276746  CO2e (t) GTP-AR2            ENE_ELET       ENE_ELET      8.765707
# 3276747           NOx (t)            ENE_ELET       ENE_ELET     38.315731
# 3276748  CO2e (t) GTP-AR4           Outra_IND           None   4836.619400
# 3276749  CO2e (t) GTP-AR5          TRAN_CARGA           None     14.203861
#
# [3276750 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ano                          0
# sigla_uf                     0
# nivel_1                      0
# nivel_2                      0
# nivel_3                      0
# nivel_4                      0
# nivel_5                      0
# nivel_6                      0
# tipo_emissao                 0
# gas                          0
# atividade_economica          0
# produto                1395600
# emissao                 317112
# dtype: int64

# %%
emissao_null = df[df['emissao'].isnull()]
emissao_null
# Out:
#           ano sigla_uf                             nivel_1  \
# 0        1970       PI  Mudança de Uso da Terra e Floresta
# 112      1970       RN  Mudança de Uso da Terra e Floresta
# 113      1970       RO  Mudança de Uso da Terra e Floresta
# 114      1970       RO  Mudança de Uso da Terra e Floresta
# 115      1970       RO  Mudança de Uso da Terra e Floresta
# ...       ...      ...                                 ...
# 1310699  1989       RN  Mudança de Uso da Terra e Floresta
# 1354183  1990       RR                        Agropecuária
# 1376220  1990       RR                        Agropecuária
# 1519306  1993       RR                        Agropecuária
# 1527012  1993       RR                        Agropecuária
#
#                                      nivel_2         nivel_3  \
# 0                  Alterações de Uso do Solo        Caatinga
# 112      Remoção por Mudança de Uso da Terra  Mata Atlântica
# 113                Alterações de Uso do Solo        Amazônia
# 114                Alterações de Uso do Solo        Amazônia
# 115                Alterações de Uso do Solo        Amazônia
# ...                                      ...             ...
# 1310699            Alterações de Uso do Solo  Mata Atlântica
# 1354183                      Solos Manejados         Diretas
# 1376220            Manejo de Dejetos Animais         Diretas
# 1519306            Manejo de Dejetos Animais         Diretas
# 1527012                      Solos Manejados         Diretas
#
#                                  nivel_4       nivel_5  \
# 0                 fora de Área Protegida  Desmatamento
# 112               fora de Área Protegida  Desmatamento
# 113                    em Área Protegida  Desmatamento
# 114                    em Área Protegida  Desmatamento
# 115               fora de Área Protegida  Desmatamento
# ...                                  ...           ...
# 1310699           fora de Área Protegida  Desmatamento
# 1354183  Aplicação de resíduos orgânicos        Animal
# 1376220                           Outros        Animal
# 1519306                           Outros        Animal
# 1527012  Aplicação de resíduos orgânicos        Animal
#
#                                                    nivel_6 tipo_emissao  \
# 0        Vegetação não florestal secundária -- Área sem...      Emissão
# 112      Vegetação não florestal secundária -- Uso agro...      Remoção
# 113      Vegetação não florestal secundária -- Uso agro...      Emissão
# 114      Vegetação não florestal secundária -- Uso agro...      Emissão
# 115      Vegetação não florestal secundária -- Uso agro...      Emissão
# ...                                                    ...          ...
# 1310699  Vegetação não florestal secundária -- Uso agro...      Emissão
# 1354183                                      Gado de Corte      Emissão
# 1376220                                      Gado de Corte      Emissão
# 1519306                                      Gado de Corte      Emissão
# 1527012                                      Gado de Corte      Emissão
#
#                       gas atividade_economica        produto  emissao
# 0        CO2e (t) GTP-AR5             AGROPEC  NÃO SE APLICA      NaN
# 112               CO2 (t)             AGROPEC  NÃO SE APLICA      NaN
# 113      CO2e (t) GWP-AR2             AGROPEC  NÃO SE APLICA      NaN
# 114      CO2e (t) GWP-AR5             AGROPEC  NÃO SE APLICA      NaN
# 115      CO2e (t) GTP-AR5             AGROPEC  NÃO SE APLICA      NaN
# ...                   ...                 ...            ...      ...
# 1310699  CO2e (t) GWP-AR5             AGROPEC  NÃO SE APLICA      NaN
# 1354183           N2O (t)                 PEC            CAR      NaN
# 1376220           N2O (t)                 PEC            CAR      NaN
# 1519306           N2O (t)                 PEC            CAR      NaN
# 1527012           N2O (t)                 PEC            CAR      NaN
#
# [317112 rows x 13 columns]

# %%
emissao_null['produto'].value_counts()
# Out:
# NÃO SE APLICA    317100
# CAR                  12
# Name: produto, dtype: int64

# %%
emissao_null['tipo_emissao'].value_counts()
# Out:
# Emissão    204272
# Remoção    112840
# Name: tipo_emissao, dtype: int64

# %%
emissao_null['nivel_5'].value_counts()
# Out:
# Desmatamento                       125580
# Outras Mudanças de uso da terra     82180
# Regeneração                         61180
# Vegetação nativa estável            40320
# NÃO SE APLICA                        7840
# Animal                                 12
# Name: nivel_5, dtype: int64
